# %%
import matplotlib.pyplot as plt
import time

# %%
# %matplotlib notebook

# %%
img_train = "./files/_temp_train_plot.png"
img_prune = "./files/_temp_prune_plot.png"
dpi = 100
im_data = plt.imread(img_train)
# img0, img1 = im_data, im_data
height, width, depth = im_data.shape
# What size does the figure need to be in inches to fit the image?
figsize = width / float(dpi), height / float(dpi) * 2 ## 2 images

fig = plt.figure(figsize=figsize)
ax2 = fig.add_axes([0,0,1,0.5])
ax = fig.add_axes([0,0.5,1,0.5])

# ax = fig.add_subplot(211)
# ax2 = fig.add_subplot(212)
plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')

while True:
    try:
        img0 = plt.imread(img_train)
        ax.clear()
        ax.axis("off")
    #     ax.axis("equal")
        ax.imshow(img0)
    except:
        pass
    
    try:
        img1 = plt.imread(img_prune)
        ax2.clear()
        ax2.axis("off")
    #     ax2.axis("equal")
        ax2.imshow(img1)
    except:
        pass
    
    fig.canvas.draw()
    plt.pause(0.5)
# Out:
# <img src="data:image/png;base64,..." width="720">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-6e5d17883294> in <module>
#      37
#      38     fig.canvas.draw()
# ---> 39     plt.pause(0.5)
#
# ~/AllFiles/ProgramFiles/miniconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in pause(interval)
#     436             canvas.draw_idle()
#     437         show(block=False)
# --> 438         canvas.start_event_loop(interval)
#     439     else:
#     440         time.sleep(interval)
#
# ~/AllFiles/ProgramFiles/miniconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in start_event_loop(self, timeout)
#    2406         while self._looping and counter * timestep < timeout:
#    2407             self.flush_events()
# -> 2408             time.sleep(timestep)
#    2409             counter += 1
#    2410
#
# KeyboardInterrupt:

# %% [markdown]
# ### Dfferent tries

# %%
# def display_image_in_actual_size(im_path):

#     dpi = 80
#     im_data = plt.imread(im_path)
#     height, width, depth = im_data.shape

#     # What size does the figure need to be in inches to fit the image?
#     figsize = width / float(dpi), height / float(dpi)

#     # Create a figure of the right size with one axes that takes up the full figure
#     fig = plt.figure(figsize=figsize)
#     ax = fig.add_axes([0, 0, 1, 1])

#     # Hide spines, ticks, etc.
#     ax.axis('off')

#     # Display the image.
#     ax.imshow(im_data, cmap='gray')

#     plt.show()

# display_image_in_actual_size("./your_image.jpg")

# %%
def pltsin(ax, colors=['b']):
    x = np.linspace(0,1,100)
    if ax.lines:
        for line in ax.lines:
            line.set_xdata(x)
            y = np.random.random(size=(100,1))
            line.set_ydata(y)
    else:
        for color in colors:
            y = np.random.random(size=(100,1))
            ax.plot(x, y, color)
    fig.canvas.draw()

# %%
fig,ax = plt.subplots(1,1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_xlim(0,1)
ax.set_ylim(0,1)
for f in range(5):
    pltsin(ax, ['b', 'r'])
    time.sleep(1)

# %%
img_train = "./files/_temp_train_plot.png"
img_prune = "./files/_temp_prune_plot.png"
dpi = 100
im_data = plt.imread(img_train)
height, width, depth = im_data.shape
# What size does the figure need to be in inches to fit the image?
figsize = width / float(dpi), height / float(dpi) * 2 ## 2 images

fig = plt.figure(figsize=figsize)
ax2 = fig.add_axes([0,0,1,0.5])
ax = fig.add_axes([0,0.5,1,0.5])

# ax = fig.add_subplot(211)
# ax2 = fig.add_subplot(212)
plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')

while True:
    img = plt.imread(img_train)
    ax.clear()
    ax.axis("off")
#     ax.axis("equal")
    ax.imshow(img)
    
    img = plt.imread(img_prune)
    ax2.clear()
    ax2.axis("off")
#     ax2.axis("equal")
    ax2.imshow(img)
    
    
    fig.canvas.draw()
    plt.pause(0.5)

# %%
from IPython.display import Image, display, clear_output

# %%
while True:
    clear_output()
    display(Image("./files/_temp_train_plot.png"))
    display(Image("./files/_temp_prune_plot.png"))
    time.sleep(0.5)

# %%
def display_image_in_actual_size(im_path):

    dpi = 100
    im_data = plt.imread(im_path)
    height, width, depth = im_data.shape

    # What size does the figure need to be in inches to fit the image?
    figsize = width / float(dpi), height / float(dpi)

    # Create a figure of the right size with one axes that takes up the full figure
    fig = plt.figure(figsize=figsize)
    ax = fig.add_axes([0, 0, 1, 1])

    # Hide spines, ticks, etc.
    ax.axis('off')

    # Display the image.
    ax.imshow(im_data, cmap='gray')

    plt.show()

display_image_in_actual_size("./files/_temp_train_plot.png")
display_image_in_actual_size("./files/_temp_train_plot.png")
