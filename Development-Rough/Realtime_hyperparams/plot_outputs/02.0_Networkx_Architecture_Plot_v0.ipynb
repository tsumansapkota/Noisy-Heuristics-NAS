# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.petersen_graph()

ax1 = plt.subplot(121)
nx.draw(G, with_labels=True, font_weight='bold')

ax2 = plt.subplot(122)
nx.draw_shell(G, nlist=[range(5, 10), range(5)], with_labels=True, font_weight='bold')

# %%
DG = nx.DiGraph()
DG.add_weighted_edges_from([(1, 2, 0.5), (3, 1, 0.05)])
DG.out_degree(1, weight='weight')

# ax1 = plt.subplot(121)
nx.draw(DG, with_labels=True, font_weight='bold')

# %%
from networkx.drawing.nx_agraph import graphviz_layout

# %%
G = nx.DiGraph()
ed = [[0, 4, -1],
 [0, 5, -1],
 [1, 4, -1],
 [1, 5, -1],
 [2, 4, -1],
 [2, 5, 10],
 [4, 3, -1],
 [5, 3, 100]]

G.add_weighted_edges_from(ed)
pos = graphviz_layout(G, prog='dot', args="-Grankdir=LR")
nx.draw(G,with_labels=True,pos=pos, font_weight='bold')

# %%
G = nx.DiGraph()
# G = nx.Graph()

# %%
G.add_node(0)
G.add_node(1)
G.add_node("input")
G.add_node(0)

G.add_edge(0, "input")

# %%
G.nodes, G.edges
# Out:
# (NodeView((0, 1, 'input')), OutEdgeView([(0, 'input')]))

# %%
nx.draw(G, with_labels=True,pos=None, font_weight='bold')

# %% [markdown]
# ### draw residual network

# %%
# https://stackoverflow.com/questions/63918432/curved-edges-in-networkx

# %%
G = nx.DiGraph()

# %%
G.add_node("I")
G.add_node("O")
G.add_edge

G.add_node("R")
